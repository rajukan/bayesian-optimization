# %% [markdown]
# # XGboost & Optuna Example

# %% [markdown]
# Example showing how to use the Optuna library (https://optuna.readthedocs.io/en/stable/) for Bayesian hyperparameter optimization (via tree of parzen estimator)

# %% [markdown]
# ## Dataset

# %%
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn import datasets


data = datasets.load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

X_train_sub, X_valid, y_train_sub, y_valid = \
    train_test_split(X_train, y_train, test_size=0.2, random_state=1, stratify=y_train)

print('Train/Valid/Test sizes:', y_train.shape[0], y_valid.shape[0], y_test.shape[0])
# Out:
# Train/Valid/Test sizes: 398 80 171

# %% [markdown]
# ## Optuna

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
import numpy as np
import optuna


def optimization_objective(trial, X_train, y_train, cv=5):


    params = {
        "n_estimators": trial.suggest_categorical("n_estimators", [30, 50, 100, 300]),

        # FIX: If you want a constant value of 0.01, don't use suggest_float.
        # If you want a range, use (low, high, step)
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, step=0.01),

        # FIX: suggest_loguniform is also deprecated; use suggest_float with log=True
        "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
    }
    

    cv_iterator = StratifiedKFold(n_splits=cv, shuffle=True, random_state=123)

    cv_scores = np.zeros(cv)
    for idx, (train_sub_idx, valid_idx) in enumerate(cv_iterator.split(X_train, y_train)):
        
        X_train_sub, X_valid = X_train[train_sub_idx], X_train[valid_idx]
        y_train_sub, y_valid = y_train[train_sub_idx], y_train[valid_idx]
        

        model = XGBClassifier(**params, random_state=123,             eval_metric="auc",
                              early_stopping_rounds=100,)
        
        model.fit(
            X_train_sub,
            y_train_sub,
            verbose=False,
            eval_set=[(X_valid, y_valid)],

        )
        
        preds = model.score(X_valid, y_valid)
        
        cv_scores[idx] = preds

    return np.mean(cv_scores)

# %%
study = optuna.create_study(direction="maximize", study_name="XGBoost Classifier")

def func(trial):
    return optimization_objective(trial, X_train, y_train)

study.optimize(func, n_trials=50);
# Out:
# [I 2026-01-18 17:39:53,398] A new study created in memory with name: XGBoost Classifier
# [I 2026-01-18 17:39:55,110] Trial 0 finished with value: 0.9446835443037973 and parameters: {'n_estimators': 300, 'learning_rate': 0.01, 'lambda': 0.8506167348629692, 'alpha': 0.23720393806200793}. Best is trial 0 with value: 0.9446835443037973.
# [I 2026-01-18 17:39:56,097] Trial 1 finished with value: 0.9623101265822784 and parameters: {'n_estimators': 100, 'learning_rate': 0.03, 'lambda': 1.2057270471915897e-06, 'alpha': 8.31513766046949e-06}. Best is trial 1 with value: 0.9623101265822784.
# [I 2026-01-18 17:39:56,702] Trial 2 finished with value: 0.9647784810126583 and parameters: {'n_estimators': 100, 'learning_rate': 0.09, 'lambda': 0.018301966337816018, 'alpha': 1.016126978148138e-06}. Best is trial 2 with value: 0.9647784810126583.
# [I 2026-01-18 17:39:57,157] Trial 3 finished with value: 0.867120253164557 and parameters: {'n_estimators': 50, 'learning_rate': 0.01, 'lambda': 4.4542385385908085e-07, 'alpha': 0.015978240389265513}. Best is trial 2 with value: 0.9647784810126583.
# [I 2026-01-18 17:39:57,802] Trial 4 finished with value: 0.9698101265822785 and parameters: {'n_estimators': 100, 'learning_rate': 0.09, 'lambda': 4.153202108833679e-06, 'alpha': 5.657076463523067e-06}. Best is trial 4 with value: 0.9698101265822785.
# [I 2026-01-18 17:39:58,702] Trial 5 finished with value: 0.9597784810126582 and parameters: {'n_estimators': 300, 'learning_rate': 0.06999999999999999, 'lambda': 2.3348804516661653e-07, 'alpha': 0.5406579368635063}. Best is trial 4 with value: 0.9698101265822785.
# [I 2026-01-18 17:39:59,310] Trial 6 finished with value: 0.9723101265822784 and parameters: {'n_estimators': 100, 'learning_rate': 0.09999999999999999, 'lambda': 1.2051542170628316e-05, 'alpha': 1.861237926708582e-05}. Best is trial 6 with value: 0.9723101265822784.
# [I 2026-01-18 17:39:59,802] Trial 7 finished with value: 0.9321202531645569 and parameters: {'n_estimators': 50, 'learning_rate': 0.01, 'lambda': 2.5594171476169966e-06, 'alpha': 0.0013000688625418155}. Best is trial 6 with value: 0.9723101265822784.
# [I 2026-01-18 17:40
finished with value: 0.9672784810126582 and parameters: {'n_estimators': 100, 'learning_rate': 0.09, 'lambda': 2.1175615839265176e-08, 'alpha': 2.4738631719896057e-08}. Best is trial 6 with value: 0.9723101265822784.
# [I 2026-01-18 17:40:16,223] Trial 34 finished with value: 0.9698101265822784 and parameters: {'n_estimators': 100, 'learning_rate': 0.08, 'lambda': 6.694803357112237e-07, 'alpha': 1.93656600669813e-07}. Best is trial 6 with value: 0.9723101265822784.
# [I 2026-01-18 17:40:16,842] Trial 35 finished with value: 0.9723101265822784 and parameters: {'n_estimators': 100, 'learning_rate': 0.09999999999999999, 'lambda': 4.12788874662099e-08, 'alpha': 2.439850945896295e-06}. Best is trial 6 with value: 0.9723101265822784.
# [I 2026-01-18 17:40:17,482] Trial 36 finished with value: 0.9697784810126583 and parameters: {'n_estimators': 100, 'learning_rate': 0.09, 'lambda': 1.7863554449951236e-06, 'alpha': 6.462267440937682e-07}. Best is trial 6 with value: 0.9723101265822784.
# [I 2026-01-18 17:40:18,012] Trial 37 finished with value: 0.8846835443037975 and parameters: {'n_estimators': 50, 'learning_rate': 0.02, 'lambda': 3.072091756112436e-07, 'alpha': 1.0482148728276325e-05}. Best is trial 6 with value: 0.9723101265822784.
# [I 2026-01-18 17:40:18,652] Trial 38 finished with value: 0.9672784810126582 and parameters: {'n_estimators': 100, 'learning_rate': 0.09, 'lambda': 1.0178345883020928e-08, 'alpha': 3.188800128344224e-08}. Best is trial 6 with value: 0.9723101265822784.
# [I 2026-01-18 17:40:19,522] Trial 39 finished with value: 0.9723101265822784 and parameters: {'n_estimators': 300, 'learning_rate': 0.09999999999999999, 'lambda': 1.1593263257043079e-07, 'alpha': 1.5937884777370797e-06}. Best is trial 6 with value: 0.9723101265822784.
# [I 2026-01-18 17:40:20,268] Trial 40 finished with value: 0.9723417721518987 and parameters: {'n_estimators': 100, 'learning_rate': 0.08, 'lambda': 5.683708051698227e-07, 'alpha': 4.383418689952337e-07}. Best is trial 40 with value: 0.9723417721518987.
# [I 2026-01-18 17:40:20,972] Trial 41 finished with value: 0.9672784810126582 and parameters: {'n_estimators': 100, 'learning_rate': 0.09, 'lambda': 8.68688285741869e-07, 'alpha': 4.5587353793784795e-06}. Best is trial 40 with value: 0.9723417721518987.
# [I 2026-01-18 17:40:21,652] Trial 42 finished with value: 0.9723101265822784 and parameters: {'n_estimators': 100, 'learning_rate': 0.09999999999999999, 'lambda': 2.6998929752116893e-08, 'alpha': 3.8480781852570887e-07}. Best is trial 40 with value: 0.9723417721518987.
# [I 2026-01-18 17:40:22,405] Trial 43 finished with value: 0.9698101265822784 and parameters: {'n_estimators': 100, 'learning_rate': 0.08, 'lambda': 4.479600650349834e-06, 'alpha': 1.3442357610172141e-07}. Best is trial 40 with value: 0.9723417721518987.
# [I 2026-01-18 17:40:22,992] Trial 44 finished with value: 0.9648101265822785 and parameters: {'n_estimators': 50, 'learning_rate': 0.06999999999999999, 'lambda': 1.5876031133565654e-07, 'alpha': 2.0059189543969505e-05}. Best is trial 40 with value: 0.9723417721518987.
# [I 2026-01-18 17:40:23,677] Trial 45 finished with value: 0.9672784810126582 and parameters: {'n_estimators': 100, 'learning_rate': 0.09, 'lambda': 4.030105787900339e-07, 'alpha': 1.9103868344838483e-08}. Best is trial 40 with value: 0.9723417721518987.
# [I 2026-01-18 17:40:24,022] Trial 46 finished with value: 0.9597784810126582 and parameters: {'n_estimators': 30, 'learning_rate': 0.060000000000000005, 'lambda': 1.988302882965027e-08, 'alpha': 0.0012753147320930772}. Best is trial 40 with value: 0.9723417721518987.
# [I 2026-01-18 17:40:24,662] Trial 47 finished with value: 0.9723101265822784 and parameters: {'n_estimators': 100, 'learning_rate': 0.09999999999999999, 'lambda': 0.0001864713307917508, 'alpha': 8.560266274340484e-07}. Best is trial 40 with value: 0.9723417721518987.
# [I 2026-01-18 17:40:25,485] Trial 48 finished with value: 0.9673101265822786 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'lambda': 1.0686806268722108e-05, 'alpha': 6.668806322979032e-08}. Best is trial 40 with value: 0.9723417721518987.
# [I 2026-01-18 17:40:26,173] Trial 49 finished with value: 0.9698101265822784 and parameters: {'n_estimators': 100, 'learning_rate': 0.08, 'lambda': 1.8089888631307661e-06, 'alpha': 3.7099943171035253e-06}. Best is trial 40 with value: 0.9723417721518987.

# %%
print(f"Best CV accuracy: {study.best_value:.5f}")
print("Best params:")

for key, value in study.best_params.items():
    print(f"\t{key}: {value}")
# Out:
# Best CV accuracy: 0.97234
# Best params:
# 	n_estimators: 100
# 	learning_rate: 0.08
# 	lambda: 5.683708051698227e-07
# 	alpha: 4.383418689952337e-07

# %%
model = XGBClassifier(**study.best_params, random_state=123, use_label_encoder=False)
model.fit(
    X_train,
    y_train,
    verbose=False,
    eval_set=[(X_valid, y_valid)],
)
# Out:
# C:\Users\gyanr\gyan-python-workspace\bayesian-optimization\.venv_3.11\Lib\site-packages\xgboost\training.py:199: UserWarning: [17:40:44] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(alpha=4.383418689952337e-07, base_score=None, booster=None,
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               lambda=5.683708051698227e-07, learning_rate=0.08, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, ...)

# %%
print(f"Training Accuracy: {model.score(X_train, y_train):0.2f}")
print(f"Test Accuracy: {model.score(X_test, y_test):0.2f}")
# Out:
# Training Accuracy: 1.00
# Test Accuracy: 0.96
